# %%
import sys
import os

PROJECT_ROOT = os.path.dirname(os.getcwd())
sys.path.insert(0, os.path.join(PROJECT_ROOT))

# %%
from src.pathgen import get_projz_file_path
from src.common.conllu_io import sentence_add_to_train

# %%
_, ewt_train_path = get_projz_file_path("Wolof", "train")
_, ewt_dev_path = get_projz_file_path("Wolof", "dev")
# Out:
# Loading from /Users/aikalee/Documents/dependency-recasting/data/raw/UD_Wolof-WTB/wo_wtb-ud-train.conllu...
# Writing into /Users/aikalee/Documents/dependency-recasting/data/common/projectivized/UD_Wolof-WTB/wo__train.conllu...
# Loading from /Users/aikalee/Documents/dependency-recasting/data/raw/UD_Wolof-WTB/wo_wtb-ud-dev.conllu...
# Writing into /Users/aikalee/Documents/dependency-recasting/data/common/projectivized/UD_Wolof-WTB/wo__dev.conllu...

# %%
sentence_add_to_train(ewt_train_path, ewt_dev_path)
# Out:
# ([('wo_wtb-ud-train_1630', 219),
#   ('wo_wtb-ud-train_1632', 221),
#   ('wo_wtb-ud-train_1632', 221),
#   ('wo_wtb-ud-train_584', 355),
#   ('wo_wtb-ud-train_1290', 404),
#   ('wo_wtb-ud-train_1330', 419)],
#  ['csubj:outer', 'advmod↓', 'ccomp↑', 'mark↑', 'conj↓', 'appos↓'])
